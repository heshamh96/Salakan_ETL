# %%
def home_page():
    print("choose your Source \n")
    print("Enter 1 for CSV \n")
    print("Enter 2 for json \n")
    print("Enter 3 for Sql-Server \n")
    print("Enter 4 for Denodo \n")
    Src_Choice=input("your Choice ...")
    return Src_Choice

# %%
import Interface as ui
# Out:
# choose your Source
#
# Enter 1 for CSV
#
# Enter 2 for json
#
# Enter 3 for Sql-Server
#
# Enter 4 for Denodo
# your Choice ... 3
# '3'

# %%
import pyodbc 
def Set_Up_SQL_Server_Connection():

# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
    server = input("Enter The Server Name")
    port=input("Enter the Port number")
    database = input("Enter the Database Name") 
    username = input("Enter your Username") 
    password = input("Enter your Password") 
    cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+','+port+';DATABASE='+database+';UID='+username+';PWD='+ password)
    cursor = cnxn.cursor()
    return cursor

# %%
Set_Up_SQL_Server_Connection()

# %%
import pandas as pd
path="/mnt/c/Users/hesham/OneDrive - Cairo University - Students/Interview Tasks/Coca-Cola/Coca_CSVs"
filename="Customers_DB_1.csv"

# %%
df =pd.read_csv(path+'/'+filename)
df
# Out:
#     Customer Code                   Customer name Customer Channel type  \
# 0          Cs 456      36- س م المهندس-منافذبولاق                    SM
# 1          Cs 457   36-K-اسواق الزهور-منافذ بولاق                Kiosks
# 2          Cs 458  36-k-البان الاصدقاء-ارض اللواء                    LG
# 3          Cs 459   36-K-اللواء ماركت-منافذ بولاق                    SG
# 4          Cs 460     36-K-س م ابوادهم-ارض اللواء                Kiosks
# ..            ...                             ...                   ...
# 464       Cs 1069            54-15-الشاعر-المتميز                Kiosks
# 465       Cs 1070            54-H-التقوي-السادس 3                    LG
# 466       Cs 1071     54-SCH-H-الكلاوى-الحى الاول                    SG
# 467       Cs 1072         54-H-SCH-الهنى-الاردنية                Kiosks
# 468       Cs 1073         54-H-16-الفايدى -الثالث                    LG
#
#       Customer coordinates X    Customer coordinates y   Number of Doors  \
# 0                   30.043400                 31.185400                3
# 1                   30.058000                 31.187800                1
# 2                   30.057700                 31.181900                2
# 3                   30.054100                 31.189600                1
# 4                   30.047300                 31.190700                2
# ..                        ...                       ...              ...
# 464                 29.986440                 30.979263                1
# 465                 29.941760                 30.933220                2
# 466                 29.968623                 30.946369                2
# 467                 29.980298                 30.942123                3
# 468                 29.964715                 30.938798                3
#
#                       Route Rep name Supervisor name Service Channel  \
# 0    36-Presales منافذبولاق   Rep 83          Sup 15            Conv
# 1    36-Presales منافذبولاق   Rep 83          Sup 15         Presell
# 2    36-Presales منافذبولاق   Rep 83          Sup 15         Presell
# 3    36-Presales منافذبولاق   Rep 83          Sup 15         Presell
# 4    36-Presales منافذبولاق   Rep 83          Sup 15         Presell
# ..                      ...      ...             ...             ...
# 464                 المتميز  Rep 104          Sup 20         Presell
# 465             Pre-السادس3  Rep 233          Sup 19         Presell
# 466                 شويبس-5  Rep 234          Sup 20         Presell
# 467                 شويبس-4  Rep 235          Sup 20            Conv
# 468             الحي الثالث   Rep 99          Sup 19            Conv
#
#             Depot USM name Region    RSM Discount
# 0     36-Bashteel    USM 8   Giza  RSM 2    1.25%
# 1     36-Bashteel    USM 8   Giza  RSM 2    0.75%
# 2     36-Bashteel    USM 8   Giza  RSM 2    1.00%
# 3     36-Bashteel    USM 8   Giza  RSM 2    0.75%
# 4     36-Bashteel    USM 8   Giza  RSM 2    1.00%
# ..            ...      ...    ...    ...      ...
# 464  54-6 October   USM 10   Giza  RSM 2    0.75%
# 465  54-6 October   USM 10   Giza  RSM 2    1.00%
# 466  54-6 October   USM 10   Giza  RSM 2    1.00%
# 467  54-6 October   USM 10   Giza  RSM 2    1.25%
# 468  54-6 October   USM 10   Giza  RSM 2    1.25%
#
# [469 rows x 15 columns]
